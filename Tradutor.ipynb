# %% [markdown]
# <a href="https://colab.research.google.com/github/JC-dojote/Aula11Nuvem/blob/main/Tradutor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Tradução

# %% [markdown]
# # Nova secção

# %%
# !pip install translate

# %%
from translate import Translator

# Texto para tradução
texto = "Hello, world! How are you today?"

# Inicializar o tradutor
translator= Translator(from_lang="en", to_lang="pt")

# Traduzir o texto
traducao = translator.translate(texto)

print("Texto original:", texto)
print("Tradução:", traducao)
# Out:
# Texto original: Hello, world! How are you today?
# Tradução: Olá, mundo! Como está hoje?

# %%
from translate import Translator

# Texto para tradução
texto = "مرحبا بالعالم!! كيف حالك اليوم؟"

# Inicializar o tradutor
translator= Translator(from_lang="ar", to_lang="pt")

# Traduzir o texto
traducao = translator.translate(texto)

print("Texto original:", texto)
print("Tradução:", traducao)
# Out:
# Texto original: مرحبا بالعالم!! كيف حالك اليوم؟
# Tradução: Olá mundo! Como está hoje?

# %%
from translate import Translator

# Texto para tradução
texto = "Hej världen!!  Hur mår du idag?"

# Inicializar o tradutor
translator= Translator(from_lang="sv", to_lang="pt")

# Traduzir o texto
traducao = translator.translate(texto)

print("Texto original:", texto)
print("Tradução:", traducao)
# Out:
# Texto original: Hej världen!!  Hur mår du idag?
# Tradução: Olá mundo!  Como está hoje?

# %%
from translate import Translator

# Texto para tradução
texto = "Γεια σου, κόσμε!!  Πώς είσαι σήμερα;"

# Inicializar o tradutor
translator= Translator(from_lang="el", to_lang="pt")

# Traduzir o texto
traducao = translator.translate(texto)

print("Texto original:", texto)
print("Tradução:", traducao)
# Out:
# Texto original: Γεια σου, κόσμε!!  Πώς είσαι σήμερα;
# Tradução: Olá, mundo!  Como está hoje?

# %%
from translate import Translator

# Texto para tradução
texto = "Szia, világ!!  Hogy vagy ma?"

# Inicializar o tradutor
translator= Translator(from_lang="hu", to_lang="pt")

# Traduzir o texto
traducao = translator.translate(texto)

print("Texto original:", texto)
print("Tradução:", traducao)
# Out:
# Texto original: Szia, világ!!  Hogy vagy ma?
# Tradução: Olá, mundo!  Como está hoje?
